# %%
# %matplotlib inline 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/nodeStatsDf.csv")

# %%
df
# Out:
#               id  in_edges_(num_followers)  out_edges_(num_following)
# 0              0                        91                         46
# 1              1                       406                        210
# 2              2                       190                         97
# 3              3                       135                        102
# 4              4                       136                         71
# ...          ...                       ...                        ...
# 4847566  4847566                         1                          0
# 4847567  4847567                         0                          1
# 4847568  4847568                         1                          1
# 4847569  4847569                         1                          0
# 4847570  4847570                        11                         10
#
# [4847571 rows x 3 columns]

# %%
df
# Out:
#               id  in_edges_(num_followers)  out_edges_(num_following)
# 0              0                        91                         46
# 1              1                       406                        210
# 2              2                       190                         97
# 3              3                       135                        102
# 4              4                       136                         71
# ...          ...                       ...                        ...
# 4847566  4847566                         1                          0
# 4847567  4847567                         0                          1
# 4847568  4847568                         1                          1
# 4847569  4847569                         1                          0
# 4847570  4847570                        11                         10
#
# [4847571 rows x 3 columns]

# %%
df.dtypes
# Out:
# id                           int64
# in_edges_(num_followers)     int64
# out_edges_(num_following)    int64
# dtype: object

# %%
df['id'].tolist()[-1]
# Out:
# 4847570

# %%
df.count() - 1
# Out:
# id                           4847570
# in_edges_(num_followers)     4847570
# out_edges_(num_following)    4847570
# dtype: int64

# %%
# df.set_index('id', inplace=True)

# %%
df.plot(x='id', figsize=(12,5), title='NodeID in and out edge counts', grid=True)

# %%
df.plot(x='id', y='in_edges_(num_followers)', figsize=(12,5), title='NodeID in edge counts', grid=True, legend=False)

# %%
df.plot(x='id', y='out_edges_(num_following)', figsize=(12,5), title='NodeID out edge counts', grid=True, legend=False)

# %%
df.plot(x='id', kind="hist")

# %%
df.describe(include= "all")
# Out:
#                  id  in_edges_(num_followers)  out_edges_(num_following)
# count  4.847571e+06              4.847571e+06               4.847571e+06
# mean   2.423785e+06              1.423265e+01               1.423265e+01
# std    1.399373e+06              4.346205e+01               3.608028e+01
# min    0.000000e+00              0.000000e+00               0.000000e+00
# 25%    1.211892e+06              1.000000e+00               1.000000e+00
# 50%    2.423785e+06              4.000000e+00               4.000000e+00
# 75%    3.635678e+06              1.300000e+01               1.400000e+01
# max    4.847570e+06              1.390600e+04               2.029300e+04

# %%
# edges_per_node = df.groupby('id')['number'].sum()

# %%
# df['total'] = df

# %%
df[['in_edges_(num_followers)','out_edges_(num_following)']].sum()
# Out:
# in_edges_(num_followers)     68993773
# out_edges_(num_following)    68993773
# dtype: int64

# %%
df['total'] = df['in_edges_(num_followers)'] + df['out_edges_(num_following)']

# %%
df.set_index('id')
# Out:
#          in_edges_(num_followers)  out_edges_(num_following)  total
# id
# 0                              91                         46    137
# 1                             406                        210    616
# 2                             190                         97    287
# 3                             135                        102    237
# 4                             136                         71    207
# ...                           ...                        ...    ...
# 4847566                         1                          0      1
# 4847567                         0                          1      1
# 4847568                         1                          1      2
# 4847569                         1                          0      1
# 4847570                        11                         10     21
#
# [4847571 rows x 3 columns]

# %%
df.plot(x='id', figsize=(12,5), grid=True)

# %%
df.plot(x='id', kind="hist")

# %%
df.plot(x='id', figsize=(12,5), grid=True, kind='line')
